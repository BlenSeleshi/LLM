# %% [markdown]
# ### Importing the Necessary Packages

# %%
import pandas as pd
import re

# %%
df = pd.read_csv(r'C:\Users\Blen\OneDrive\Desktop\10Academy\LLM\data\cleaned_v4.csv')

# %%
df.head()
# Out:
#   Channel Title Channel Username    ID  \
# 0        ምርጥ ዕቃ        @MerttEka  6815
# 1        ምርጥ ዕቃ        @MerttEka  6811
# 2        ምርጥ ዕቃ        @MerttEka  6810
# 3        ምርጥ ዕቃ        @MerttEka  6806
# 4        ምርጥ ዕቃ        @MerttEka  6805
#
#                                              Message  \
# 0                           ይሄንን ./ ተጭነው  ያድርጉ፣ ቤተሰብ
# 1  የእናት ጡት ወተት ማጠራቀሚያ\n ከውስጥ ልብስዎ ጋር አብረው የሚለብሱትና...
# 2  በቻርጅ የሚሰራ የጃር ውሃ ፓምፕ\n    ለሁሉም ዓይነት የውሃ ጃሮች ይሆ...
# 3  2 1 \n\n የልብስ መተኮሻ\n በእንፏሎት የሚሰራ ባለ 3 ወፍራም ምሶሶ...
# 4                       ይሄንን ./ ተጭነው  ያድርጉ፣ ቤተሰብ ይሁኑ
#
#                         Date                 Media Path
# 0  2024-09-27 18:15:44+00:00                        NaN
# 1  2024-09-27 18:14:53+00:00  photos\@MerttEka_6811.jpg
# 2  2024-09-27 14:19:03+00:00                        NaN
# 3  2024-09-27 11:42:32+00:00  photos\@MerttEka_6806.jpg
# 4  2024-09-26 16:38:22+00:00                        NaN

# %% [markdown]
# ### Checking for Missing Values

# %%
print("Checking for NaN values in the 'Message' column:")
nan_count = df['Message'].isnull().sum()
print(f"Number of NaN values in 'Message' column: {nan_count}")
# Out:
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 544

# %% [markdown]
# ### Handling Missing Values

# %%
df = df.dropna(subset=['Message'])

# Print the shape of the dataset after dropping NaN values in the "Message" column
print(f"Dataset shape after dropping NaN values in 'Message' column: {df.shape}")
# Out:
# Dataset shape after dropping NaN values in 'Message' column: (3617, 6)

# %% [markdown]
# ### Removing unwanted phrases from the dataset

# %%
unwanted_phrases = [
    'ይሄንን ./ ተጭነው  ያድርጉ፣ ቤተሰብ ይሁኑ',
    'ይሄንን ./ ተጭነው  ያድርጉ፣ ቤተሰብ'
    
]

def remove_unwanted_phrases(message):
    for phrase in unwanted_phrases:
        message = message.replace(phrase, '')  
    return message

# %%
df['Message'] = df['Message'].apply(remove_unwanted_phrases)

# %%
df.head()
# Out:
#   Channel Title Channel Username    ID  \
# 0        ምርጥ ዕቃ        @MerttEka  6815
# 1        ምርጥ ዕቃ        @MerttEka  6811
# 2        ምርጥ ዕቃ        @MerttEka  6810
# 3        ምርጥ ዕቃ        @MerttEka  6806
# 4        ምርጥ ዕቃ        @MerttEka  6805
#
#                                              Message  \
# 0
# 1  የእናት ጡት ወተት ማጠራቀሚያ\n ከውስጥ ልብስዎ ጋር አብረው የሚለብሱትና...
# 2  በቻርጅ የሚሰራ የጃር ውሃ ፓምፕ\n    ለሁሉም ዓይነት የውሃ ጃሮች ይሆ...
# 3  2 1 \n\n የልብስ መተኮሻ\n በእንፏሎት የሚሰራ ባለ 3 ወፍራም ምሶሶ...
# 4
#
#                         Date                 Media Path
# 0  2024-09-27 18:15:44+00:00                        NaN
# 1  2024-09-27 18:14:53+00:00  photos\@MerttEka_6811.jpg
# 2  2024-09-27 14:19:03+00:00                        NaN
# 3  2024-09-27 11:42:32+00:00  photos\@MerttEka_6806.jpg
# 4  2024-09-26 16:38:22+00:00                        NaN

# %% [markdown]
# ### Removing everything outside Amharic characters from the first line

# %%
# Function to remove everything outside Amharic characters from the first line
def clean_first_line(text):
    # Split the text by lines
    lines = text.split('\n')
    
    if not lines:
        return text  # If there are no lines, return the original text
    
    # Regex to match only Amharic characters and common punctuation (optional)
    # \u1200-\u137F: Amharic Unicode block
    # \s: whitespace
    # You can include more punctuation if necessary
    amharic_only = re.sub(r'[^\u1200-\u137F\s]', '', lines[0]).strip()
    
    # Check if the cleaned first line is empty
    if amharic_only:
        # If not empty, replace the first line with the cleaned version
        # If there are more lines, join them with the cleaned first line
        if len(lines) > 1:
            cleaned_message = amharic_only + '\n' + '\n'.join(lines[1:])
        else:
            cleaned_message = amharic_only
    else:
        # If empty, remove the first line and join the remaining lines
        if len(lines) > 1:
            cleaned_message = '\n'.join(lines[1:]).lstrip('\n')  # Remove leading newlines
        else:
            cleaned_message = ''  # If there's only one line and it's empty, return empty string
    
    return cleaned_message

# %%
# Apply the function to the 'messages' column
df['Messages_cleaned'] = df['Message'].apply(clean_first_line)

# %%
df.head()
# Out:
#   Channel Title Channel Username    ID  \
# 0        ምርጥ ዕቃ        @MerttEka  6815
# 1        ምርጥ ዕቃ        @MerttEka  6811
# 2        ምርጥ ዕቃ        @MerttEka  6810
# 3        ምርጥ ዕቃ        @MerttEka  6806
# 4        ምርጥ ዕቃ        @MerttEka  6805
#
#                                              Message  \
# 0
# 1  የእናት ጡት ወተት ማጠራቀሚያ\n ከውስጥ ልብስዎ ጋር አብረው የሚለብሱትና...
# 2  በቻርጅ የሚሰራ የጃር ውሃ ፓምፕ\n    ለሁሉም ዓይነት የውሃ ጃሮች ይሆ...
# 3  2 1 \n\n የልብስ መተኮሻ\n በእንፏሎት የሚሰራ ባለ 3 ወፍራም ምሶሶ...
# 4
#
#                         Date                 Media Path  \
# 0  2024-09-27 18:15:44+00:00                        NaN
# 1  2024-09-27 18:14:53+00:00  photos\@MerttEka_6811.jpg
# 2  2024-09-27 14:19:03+00:00                        NaN
# 3  2024-09-27 11:42:32+00:00  photos\@MerttEka_6806.jpg
# 4  2024-09-26 16:38:22+00:00                        NaN
#
#                                     Messages_cleaned
# 0
# 1  የእናት ጡት ወተት ማጠራቀሚያ\n ከውስጥ ልብስዎ ጋር አብረው የሚለብሱትና...
# 2  በቻርጅ የሚሰራ የጃር ውሃ ፓምፕ\n    ለሁሉም ዓይነት የውሃ ጃሮች ይሆ...
# 3   የልብስ መተኮሻ\n በእንፏሎት የሚሰራ ባለ 3 ወፍራም ምሶሶ መቆሚያ ያለ...
# 4

# %%
df.tail(100)
# Out:
#      Channel Title Channel Username   ID  \
# 4059        ምርጥ ዕቃ        @MerttEka  332
# 4060        ምርጥ ዕቃ        @MerttEka  331
# 4061        ምርጥ ዕቃ        @MerttEka  330
# 4062        ምርጥ ዕቃ        @MerttEka  322
# 4063        ምርጥ ዕቃ        @MerttEka  317
# ...            ...              ...  ...
# 4156        ምርጥ ዕቃ        @MerttEka   44
# 4157        ምርጥ ዕቃ        @MerttEka   43
# 4158        ምርጥ ዕቃ        @MerttEka   32
# 4159        ምርጥ ዕቃ        @MerttEka   30
# 4160        ምርጥ ዕቃ        @MerttEka   23
#
#                                                 Message  \
# 4059  . ሩዝ ወይንም መንኛውንም ነገር በእንፏሎት የሚያበስል። በተለይ ደሞ የህ...
# 4060  ለምግብ ዝግጅት አስፈላጊ የሆነ ዲጂታል ሚዛን። እስከ 5 ኪሎ መመዘን የሚ...
# 4061  የኬክ ወይንም ማቅረቢያ \nየቱርክ ስሪት የሆነ ቆንጆ ዕቃ። 1000 ብር ...
# 4062  በቻርጅ የሚሰራ 381ሚሊ ጁስ የሚይዝ ለአያያዝ ምቹ የሆነ የጁስ መፍጫ። ...
# 4063  . 12 ስኒ ቡና በፍጥነት ጨምቆ ያፈላል። ለቤት ወይም ለቢሮ አስፈላጊ የ...
# ...                                                 ...
# 4156                                               2500
# 4157                                ዋጋ 2500\n0983063957
# 4158  የሙያ ባለቤት መሆን መሠልጠን ነው።\nቀለም ቀቢ ሳያስፈልግዎ ቤትዎን ወይ...
# 4159  ቤትና ግቢዎን እንዲሁም የብረት እና የእንጨት ቁሳቁስዎን ቀለም ቀቢ ሳያስ...
# 4160                                        ለማዘዝ\n ://.
#
#                            Date                Media Path  \
# 4059  2020-08-21 13:44:46+00:00  photos\@MerttEka_332.jpg
# 4060  2020-08-20 13:08:36+00:00  photos\@MerttEka_331.jpg
# 4061  2020-08-20 13:05:31+00:00  photos\@MerttEka_330.jpg
# 4062  2020-08-13 20:47:47+00:00                       NaN
# 4063  2020-08-13 20:15:53+00:00  photos\@MerttEka_317.jpg
# ...                         ...                       ...
# 4156  2019-11-13 10:01:12+00:00                       NaN
# 4157  2019-11-13 10:00:40+00:00                       NaN
# 4158  2019-11-09 04:44:54+00:00                       NaN
# 4159  2019-10-31 07:06:25+00:00                       NaN
# 4160  2019-10-27 13:38:49+00:00                       NaN
#
#                                        Messages_cleaned
# 4059  ሩዝ ወይንም መንኛውንም ነገር በእንፏሎት የሚያበስል። በተለይ ደሞ የህክም...
# 4060  ለምግብ ዝግጅት አስፈላጊ የሆነ ዲጂታል ሚዛን። እስከ  ኪሎ መመዘን የሚች...
# 4061  የኬክ ወይንም ማቅረቢያ\nየቱርክ ስሪት የሆነ ቆንጆ ዕቃ። 1000 ብር ብ...
# 4062  በቻርጅ የሚሰራ ሚሊ ጁስ የሚይዝ ለአያያዝ ምቹ የሆነ የጁስ መፍጫ። በመኪ...
# 4063  ስኒ ቡና በፍጥነት ጨምቆ ያፈላል። ለቤት ወይም ለቢሮ አስፈላጊ የቡና ማፍ...
# ...                                                 ...
# 4156
# 4157                                     ዋጋ\n0983063957
# 4158  የሙያ ባለቤት መሆን መሠልጠን ነው።\nቀለም ቀቢ ሳያስፈልግዎ ቤትዎን ወይ...
# 4159  ቤትና ግቢዎን እንዲሁም የብረት እና የእንጨት ቁሳቁስዎን ቀለም ቀቢ ሳያስ...
# 4160                                        ለማዘዝ\n ://.
#
# [100 rows x 7 columns]

# %% [markdown]
# ### Replacing :: with a Newline

# %%
# Function to replace ። with a newline character
def replace_full_stop_with_newline(text):
    return text.replace('።', '\n')

# Apply the function to the 'messages' column
df['Messages_cleaned'] = df['Messages_cleaned'].apply(replace_full_stop_with_newline)

# %%
df.tail(100)
# Out:
#      Channel Title Channel Username   ID  \
# 4059        ምርጥ ዕቃ        @MerttEka  332
# 4060        ምርጥ ዕቃ        @MerttEka  331
# 4061        ምርጥ ዕቃ        @MerttEka  330
# 4062        ምርጥ ዕቃ        @MerttEka  322
# 4063        ምርጥ ዕቃ        @MerttEka  317
# ...            ...              ...  ...
# 4156        ምርጥ ዕቃ        @MerttEka   44
# 4157        ምርጥ ዕቃ        @MerttEka   43
# 4158        ምርጥ ዕቃ        @MerttEka   32
# 4159        ምርጥ ዕቃ        @MerttEka   30
# 4160        ምርጥ ዕቃ        @MerttEka   23
#
#                                                 Message  \
# 4059  . ሩዝ ወይንም መንኛውንም ነገር በእንፏሎት የሚያበስል። በተለይ ደሞ የህ...
# 4060  ለምግብ ዝግጅት አስፈላጊ የሆነ ዲጂታል ሚዛን። እስከ 5 ኪሎ መመዘን የሚ...
# 4061  የኬክ ወይንም ማቅረቢያ \nየቱርክ ስሪት የሆነ ቆንጆ ዕቃ። 1000 ብር ...
# 4062  በቻርጅ የሚሰራ 381ሚሊ ጁስ የሚይዝ ለአያያዝ ምቹ የሆነ የጁስ መፍጫ። ...
# 4063  . 12 ስኒ ቡና በፍጥነት ጨምቆ ያፈላል። ለቤት ወይም ለቢሮ አስፈላጊ የ...
# ...                                                 ...
# 4156                                               2500
# 4157                                ዋጋ 2500\n0983063957
# 4158  የሙያ ባለቤት መሆን መሠልጠን ነው።\nቀለም ቀቢ ሳያስፈልግዎ ቤትዎን ወይ...
# 4159  ቤትና ግቢዎን እንዲሁም የብረት እና የእንጨት ቁሳቁስዎን ቀለም ቀቢ ሳያስ...
# 4160                                        ለማዘዝ\n ://.
#
#                            Date                Media Path  \
# 4059  2020-08-21 13:44:46+00:00  photos\@MerttEka_332.jpg
# 4060  2020-08-20 13:08:36+00:00  photos\@MerttEka_331.jpg
# 4061  2020-08-20 13:05:31+00:00  photos\@MerttEka_330.jpg
# 4062  2020-08-13 20:47:47+00:00                       NaN
# 4063  2020-08-13 20:15:53+00:00  photos\@MerttEka_317.jpg
# ...                         ...                       ...
# 4156  2019-11-13 10:01:12+00:00                       NaN
# 4157  2019-11-13 10:00:40+00:00                       NaN
# 4158  2019-11-09 04:44:54+00:00                       NaN
# 4159  2019-10-31 07:06:25+00:00                       NaN
# 4160  2019-10-27 13:38:49+00:00                       NaN
#
#                                        Messages_cleaned
# 4059  ሩዝ ወይንም መንኛውንም ነገር በእንፏሎት የሚያበስል\n በተለይ ደሞ የህክ...
# 4060  ለምግብ ዝግጅት አስፈላጊ የሆነ ዲጂታል ሚዛን\n እስከ  ኪሎ መመዘን የሚ...
# 4061  የኬክ ወይንም ማቅረቢያ\nየቱርክ ስሪት የሆነ ቆንጆ ዕቃ\n 1000 ብር ...
# 4062  በቻርጅ የሚሰራ ሚሊ ጁስ የሚይዝ ለአያያዝ ምቹ የሆነ የጁስ መፍጫ\n በመ...
# 4063  ስኒ ቡና በፍጥነት ጨምቆ ያፈላል\n ለቤት ወይም ለቢሮ አስፈላጊ የቡና ማ...
# ...                                                 ...
# 4156
# 4157                                     ዋጋ\n0983063957
# 4158  የሙያ ባለቤት መሆን መሠልጠን ነው\n\nቀለም ቀቢ ሳያስፈልግዎ ቤትዎን ወ...
# 4159  ቤትና ግቢዎን እንዲሁም የብረት እና የእንጨት ቁሳቁስዎን ቀለም ቀቢ ሳያስ...
# 4160                                        ለማዘዝ\n ://.
#
# [100 rows x 7 columns]

# %%
df = df.drop(columns=['Message'])

# %%
df.head()
# Out:
#   Channel Title Channel Username    ID                       Date  \
# 0        ምርጥ ዕቃ        @MerttEka  6815  2024-09-27 18:15:44+00:00
# 1        ምርጥ ዕቃ        @MerttEka  6811  2024-09-27 18:14:53+00:00
# 2        ምርጥ ዕቃ        @MerttEka  6810  2024-09-27 14:19:03+00:00
# 3        ምርጥ ዕቃ        @MerttEka  6806  2024-09-27 11:42:32+00:00
# 4        ምርጥ ዕቃ        @MerttEka  6805  2024-09-26 16:38:22+00:00
#
#                   Media Path  \
# 0                        NaN
# 1  photos\@MerttEka_6811.jpg
# 2                        NaN
# 3  photos\@MerttEka_6806.jpg
# 4                        NaN
#
#                                     Messages_cleaned
# 0
# 1  የእናት ጡት ወተት ማጠራቀሚያ\n ከውስጥ ልብስዎ ጋር አብረው የሚለብሱትና...
# 2  በቻርጅ የሚሰራ የጃር ውሃ ፓምፕ\n    ለሁሉም ዓይነት የውሃ ጃሮች ይሆ...
# 3   የልብስ መተኮሻ\n በእንፏሎት የሚሰራ ባለ 3 ወፍራም ምሶሶ መቆሚያ ያለ...
# 4

# %%
df = df[df['Messages_cleaned'] != '']

# %%
df.head()
# Out:
#   Channel Title Channel Username    ID                       Date  \
# 1        ምርጥ ዕቃ        @MerttEka  6811  2024-09-27 18:14:53+00:00
# 2        ምርጥ ዕቃ        @MerttEka  6810  2024-09-27 14:19:03+00:00
# 3        ምርጥ ዕቃ        @MerttEka  6806  2024-09-27 11:42:32+00:00
# 5        ምርጥ ዕቃ        @MerttEka  6802  2024-09-26 16:16:51+00:00
# 6        ምርጥ ዕቃ        @MerttEka  6801  2024-09-26 12:31:45+00:00
#
#                   Media Path  \
# 1  photos\@MerttEka_6811.jpg
# 2                        NaN
# 3  photos\@MerttEka_6806.jpg
# 5  photos\@MerttEka_6802.jpg
# 6  photos\@MerttEka_6801.jpg
#
#                                     Messages_cleaned
# 1  የእናት ጡት ወተት ማጠራቀሚያ\n ከውስጥ ልብስዎ ጋር አብረው የሚለብሱትና...
# 2  በቻርጅ የሚሰራ የጃር ውሃ ፓምፕ\n    ለሁሉም ዓይነት የውሃ ጃሮች ይሆ...
# 3   የልብስ መተኮሻ\n በእንፏሎት የሚሰራ ባለ 3 ወፍራም ምሶሶ መቆሚያ ያለ...
# 5  የመኪና መዓዛ\n በፀሃይ ብርሃን ስለሚሰራ ቻርጅ ማድረግ አይፈልግም\n ሁ...
# 6   የፀጉር ማድረቂያ ፎን\n6000 በጣም ፈጣን\nማበጠሪያ ያለው\n ሶኬቱ ...

# %%
df.to_csv('cleaned_V6.csv', index=False)  # Save without index
